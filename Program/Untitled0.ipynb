# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

# %%
from SimPEG import Mesh, Utils

# %%
mesh = Mesh.TensorMesh([100, 100])
model = Utils.ModelBuilder.randomModel(mesh.vnC)
# Out:
# Using a seed of:  865

# %%
plt.imshow(model, cmap = 'RdPu')

# %%
plt.imshow(model, cmap = 'Spectral')

# %%
plt.imshow(model, cmap = 'gnuplot2')

# %%
# !pwd
# Out:
# /Users/sgkang/Projects/IPresearch/Program

# %%
import Image

# %%
img = Image.open("sg.jpg")

# %%
img_array = np.asarray(img.convert('L'))

# %%
# plt.imshow(img_array, cmap = 'rainbow')
# plt.imshow(img_array, cmap = 'RdPu')
plt.imshow(1./(img_array+40.), cmap = 'RdPu')
# plt.imshow(1./(img_array+40.), cmap = 'Spectral')
# plt.colo|rbar()
plt.xticks([])
plt.yticks([])
plt.savefig('sg.png')

# %%
img_array.shapedd
# Out:
# (720, 1080)

# %%
mesh = Mesh.TensorMesh([720, 1080])

# %%
Ave = mesh.aveCC2F

# %%
Ave.shape
# Out:
# (1557000, 777600)

# %%
img_array_smooth = img_array_smooth.reshape(img_array.shape)

# %%
plt.imshow(img_array_smooth, cmap = 'RdPu')
